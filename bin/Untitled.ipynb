# %%
# %matplotlib inline
import yt
import numpy as np 
import matplotlib.pyplot as plt
from matplotlib import pylab

# %%
ds = yt.load("TaylorGreen.0000.vtk")
#ds.field_list
#print(ds.field_info["gas","velocity_x"].get_units())
#ds.derived_field_list
yt.SlicePlot(ds,"y","vorticity_y",origin= "native")
#yt.SlicePlot(ds,"z","magnetic_field_z",origin= "native")
#yt.SlicePlot(ds,"x","momentum_x")
#ds.print_stats()

#ds = yt.load("TaylorGreen.0066.vtk")
#p=yt.SlicePlot(ds,"z", "velocity_z", origin= "native")
#p.annotate_quiver('velocity_x', 'velocity_y')
#p.save()
# Out:
# yt : [INFO     ] 2017-06-12 17:26:26,877 Temporarily setting domain_right_edge = -domain_left_edge. This will be corrected automatically if it is not the case.
# yt : [WARNING  ] 2017-06-12 17:26:26,878 Assuming 1.0 = 1.0 cm
# yt : [WARNING  ] 2017-06-12 17:26:26,879 Assuming 1.0 = 1.0 s
# yt : [WARNING  ] 2017-06-12 17:26:26,879 Assuming 1.0 = 1.0 g
# yt : [INFO     ] 2017-06-12 17:26:26,884 Parameters: current_time              = 0.0
# yt : [INFO     ] 2017-06-12 17:26:26,884 Parameters: domain_dimensions         = [0 0 0]
# yt : [INFO     ] 2017-06-12 17:26:26,885 Parameters: domain_left_edge          = [ 0.  0.  0.]
# yt : [INFO     ] 2017-06-12 17:26:26,886 Parameters: domain_right_edge         = [-0. -0. -0.]
# yt : [INFO     ] 2017-06-12 17:26:26,886 Parameters: cosmological_simulation   = 0.0
# yt : [INFO     ] 2017-06-12 17:26:28,643 xlim = 0.000000 6.280000
# yt : [INFO     ] 2017-06-12 17:26:28,643 ylim = 0.000000 6.280000
# yt : [INFO     ] 2017-06-12 17:26:28,644 xlim = 0.000000 6.280000
# yt : [INFO     ] 2017-06-12 17:26:28,645 ylim = 0.000000 6.280000
# yt : [INFO     ] 2017-06-12 17:26:28,646 Making a fixed resolution buffer of (('gas', 'vorticity_y')) 800 by 800
# yt : [WARNING  ] 2017-06-12 17:26:28,670 Plot image for field ('gas', 'vorticity_y') has both positive and negative values. Min = -0.000999, Max = 0.000999.
# yt : [WARNING  ] 2017-06-12 17:26:28,671 Switching to symlog colorbar scaling unless linear scaling is specified later
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
ds = yt.load("TaylorGreen.0005.vtk")
#ds.print_stats()
#ds.field_list
#ds.derived_field_list
yt.SlicePlot(ds,"z","magnetic_field_z", origin= "native")

#ds.save()
# Out:
# yt : [INFO     ] 2017-06-12 15:10:44,420 Temporarily setting domain_right_edge = -domain_left_edge. This will be corrected automatically if it is not the case.
# yt : [WARNING  ] 2017-06-12 15:10:44,421 Assuming 1.0 = 1.0 cm
# yt : [WARNING  ] 2017-06-12 15:10:44,421 Assuming 1.0 = 1.0 s
# yt : [WARNING  ] 2017-06-12 15:10:44,422 Assuming 1.0 = 1.0 g
# yt : [INFO     ] 2017-06-12 15:10:44,426 Parameters: current_time              = 0.2533309
# yt : [INFO     ] 2017-06-12 15:10:44,426 Parameters: domain_dimensions         = [0 0 0]
# yt : [INFO     ] 2017-06-12 15:10:44,427 Parameters: domain_left_edge          = [ 0.  0.  0.]
# yt : [INFO     ] 2017-06-12 15:10:44,428 Parameters: domain_right_edge         = [-0. -0. -0.]
# yt : [INFO     ] 2017-06-12 15:10:44,429 Parameters: cosmological_simulation   = 0.0
# yt : [INFO     ] 2017-06-12 15:10:45,333 xlim = 0.000000 6.280000
# yt : [INFO     ] 2017-06-12 15:10:45,333 ylim = 0.000000 6.280000
# yt : [INFO     ] 2017-06-12 15:10:45,335 xlim = 0.000000 6.280000
# yt : [INFO     ] 2017-06-12 15:10:45,335 ylim = 0.000000 6.280000
# yt : [INFO     ] 2017-06-12 15:10:45,336 Making a fixed resolution buffer of (('gas', 'magnetic_field_z')) 800 by 800
# yt : [WARNING  ] 2017-06-12 15:10:45,367 Plot image for field ('gas', 'magnetic_field_z') has both positive and negative values. Min = -0.683000, Max = 0.683012.
# yt : [WARNING  ] 2017-06-12 15:10:45,367 Switching to symlog colorbar scaling unless linear scaling is specified later
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
# Out:
# yt : [INFO     ] 2017-06-07 16:54:39,993 Temporarily setting domain_right_edge = -domain_left_edge. This will be corrected automatically if it is not the case.
# yt : [WARNING  ] 2017-06-07 16:54:39,994 Assuming 1.0 = 1.0 cm
# yt : [WARNING  ] 2017-06-07 16:54:39,995 Assuming 1.0 = 1.0 s
# yt : [WARNING  ] 2017-06-07 16:54:39,995 Assuming 1.0 = 1.0 g
# yt : [INFO     ] 2017-06-07 16:54:40,000 Parameters: current_time              = 0.02506989
# yt : [INFO     ] 2017-06-07 16:54:40,000 Parameters: domain_dimensions         = [0 0 0]
# yt : [INFO     ] 2017-06-07 16:54:40,002 Parameters: domain_left_edge          = [ 0.  0.  0.]
# yt : [INFO     ] 2017-06-07 16:54:40,002 Parameters: domain_right_edge         = [-0. -0. -0.]
# yt : [INFO     ] 2017-06-07 16:54:40,003 Parameters: cosmological_simulation   = 0.0
# yt : [INFO     ] 2017-06-07 16:54:40,955 xlim = 0.000000 6.280000
# yt : [INFO     ] 2017-06-07 16:54:40,956 ylim = 0.000000 6.280000
# yt : [INFO     ] 2017-06-07 16:54:40,957 xlim = 0.000000 6.280000
# yt : [INFO     ] 2017-06-07 16:54:40,957 ylim = 0.000000 6.280000
# yt : [INFO     ] 2017-06-07 16:54:40,959 Making a fixed resolution buffer of (('gas', 'velocity_z')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
ds = yt.load("TaylorGreen.0105.vtk")
yt.SlicePlot(ds,"y","momentum_y",origin= "native")
# Out:
# yt : [INFO     ] 2017-05-31 14:43:29,431 Temporarily setting domain_right_edge = -domain_left_edge. This will be corrected automatically if it is not the case.
# yt : [WARNING  ] 2017-05-31 14:43:29,432 Assuming 1.0 = 1.0 cm
# yt : [WARNING  ] 2017-05-31 14:43:29,432 Assuming 1.0 = 1.0 s
# yt : [WARNING  ] 2017-05-31 14:43:29,432 Assuming 1.0 = 1.0 g
# yt : [INFO     ] 2017-05-31 14:43:29,436 Parameters: current_time              = 5.261087
# yt : [INFO     ] 2017-05-31 14:43:29,437 Parameters: domain_dimensions         = [0 0 0]
# yt : [INFO     ] 2017-05-31 14:43:29,438 Parameters: domain_left_edge          = [ 0.  0.  0.]
# yt : [INFO     ] 2017-05-31 14:43:29,439 Parameters: domain_right_edge         = [-0. -0. -0.]
# yt : [INFO     ] 2017-05-31 14:43:29,439 Parameters: cosmological_simulation   = 0.0
# yt : [INFO     ] 2017-05-31 14:43:30,361 xlim = 0.000000 6.280000
# yt : [INFO     ] 2017-05-31 14:43:30,362 ylim = 0.000000 6.280000
# yt : [INFO     ] 2017-05-31 14:43:30,363 xlim = 0.000000 6.280000
# yt : [INFO     ] 2017-05-31 14:43:30,363 ylim = 0.000000 6.280000
# yt : [INFO     ] 2017-05-31 14:43:30,364 Making a fixed resolution buffer of (('athena', 'momentum_y')) 800 by 800
# yt : [WARNING  ] 2017-05-31 14:43:30,386 Plot image for field ('athena', 'momentum_y') has both positive and negative values. Min = -0.332508, Max = 0.239786.
# yt : [WARNING  ] 2017-05-31 14:43:30,387 Switching to symlog colorbar scaling unless linear scaling is specified later
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
ds = yt.load("TaylorGreen.0120.vtk")
#yt.SlicePlot(ds,"y","cell_centered_B_y",origin= "native")
yt.SlicePlot(ds,"y","momentum_y",origin= "native")
#yt.SlicePlot(ds,"x","momentum_x")
# Out:
# yt : [INFO     ] 2017-06-01 13:23:07,979 Temporarily setting domain_right_edge = -domain_left_edge. This will be corrected automatically if it is not the case.
# yt : [WARNING  ] 2017-06-01 13:23:07,980 Assuming 1.0 = 1.0 cm
# yt : [WARNING  ] 2017-06-01 13:23:07,981 Assuming 1.0 = 1.0 s
# yt : [WARNING  ] 2017-06-01 13:23:07,981 Assuming 1.0 = 1.0 g
# yt : [INFO     ] 2017-06-01 13:23:07,985 Parameters: current_time              = 6.011171
# yt : [INFO     ] 2017-06-01 13:23:07,985 Parameters: domain_dimensions         = [0 0 0]
# yt : [INFO     ] 2017-06-01 13:23:07,986 Parameters: domain_left_edge          = [ 0.  0.  0.]
# yt : [INFO     ] 2017-06-01 13:23:07,987 Parameters: domain_right_edge         = [-0. -0. -0.]
# yt : [INFO     ] 2017-06-01 13:23:07,987 Parameters: cosmological_simulation   = 0.0
# yt : [INFO     ] 2017-06-01 13:23:08,876 xlim = 0.000000 6.280000
# yt : [INFO     ] 2017-06-01 13:23:08,877 ylim = 0.000000 6.280000
# yt : [INFO     ] 2017-06-01 13:23:08,878 xlim = 0.000000 6.280000
# yt : [INFO     ] 2017-06-01 13:23:08,878 ylim = 0.000000 6.280000
# yt : [INFO     ] 2017-06-01 13:23:08,881 Making a fixed resolution buffer of (('athena', 'momentum_y')) 800 by 800
# yt : [WARNING  ] 2017-06-01 13:23:08,901 Plot image for field ('athena', 'momentum_y') has both positive and negative values. Min = -0.337112, Max = 0.271176.
# yt : [WARNING  ] 2017-06-01 13:23:08,902 Switching to symlog colorbar scaling unless linear scaling is specified later
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
# Out:
# yt : [INFO     ] 2017-06-01 14:17:42,470 Temporarily setting domain_right_edge = -domain_left_edge. This will be corrected automatically if it is not the case.
# yt : [WARNING  ] 2017-06-01 14:17:42,471 Assuming 1.0 = 1.0 cm
# yt : [WARNING  ] 2017-06-01 14:17:42,472 Assuming 1.0 = 1.0 s
# yt : [WARNING  ] 2017-06-01 14:17:42,472 Assuming 1.0 = 1.0 g
# yt : [INFO     ] 2017-06-01 14:17:42,476 Parameters: current_time              = 0.05013973
# yt : [INFO     ] 2017-06-01 14:17:42,477 Parameters: domain_dimensions         = [0 0 0]
# yt : [INFO     ] 2017-06-01 14:17:42,478 Parameters: domain_left_edge          = [ 0.  0.  0.]
# yt : [INFO     ] 2017-06-01 14:17:42,478 Parameters: domain_right_edge         = [-0. -0. -0.]
# yt : [INFO     ] 2017-06-01 14:17:42,479 Parameters: cosmological_simulation   = 0.0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-88d6b38602b5> in <module>()
#       4 U=np.array(s["velocity_x"])
#       5 V=np.array(s["velocity_y"])
# ----> 6 X, Y = np.linspace(0,7,101)
#       7 plt.quiver(X, Y, U, V, alpha=.5)
#
# ValueError: too many values to unpack (expected 2)

# %%
ds = yt.load("TaylorGreen.0001.vtk")
p=yt.SlicePlot(ds, 'x', 'velocity_x', origin= "native")
#ds.derived_field_list
#p.annotate_magnetic_field()
#
#p.annotate_velocity(factor = 16)
#p.annotate_quiver( 'x', 'y', pivot='tip')
#p.save()
# Out:
# yt : [INFO     ] 2017-06-02 13:33:09,854 Temporarily setting domain_right_edge = -domain_left_edge. This will be corrected automatically if it is not the case.
# yt : [WARNING  ] 2017-06-02 13:33:09,855 Assuming 1.0 = 1.0 cm
# yt : [WARNING  ] 2017-06-02 13:33:09,856 Assuming 1.0 = 1.0 s
# yt : [WARNING  ] 2017-06-02 13:33:09,856 Assuming 1.0 = 1.0 g
# yt : [INFO     ] 2017-06-02 13:33:09,860 Parameters: current_time              = 0.02506989
# yt : [INFO     ] 2017-06-02 13:33:09,861 Parameters: domain_dimensions         = [0 0 0]
# yt : [INFO     ] 2017-06-02 13:33:09,861 Parameters: domain_left_edge          = [ 0.  0.  0.]
# yt : [INFO     ] 2017-06-02 13:33:09,862 Parameters: domain_right_edge         = [-0. -0. -0.]
# yt : [INFO     ] 2017-06-02 13:33:09,863 Parameters: cosmological_simulation   = 0.0
# yt : [INFO     ] 2017-06-02 13:33:10,779 xlim = 0.000000 6.280000
# yt : [INFO     ] 2017-06-02 13:33:10,779 ylim = 0.000000 6.280000
# yt : [INFO     ] 2017-06-02 13:33:10,780 xlim = 0.000000 6.280000
# yt : [INFO     ] 2017-06-02 13:33:10,781 ylim = 0.000000 6.280000
# yt : [INFO     ] 2017-06-02 13:33:10,782 Making a fixed resolution buffer of (('gas', 'velocity_x')) 800 by 800
# yt : [WARNING  ] 2017-06-02 13:33:10,808 Plot image for field ('gas', 'velocity_x') has both positive and negative values. Min = -0.000003, Max = 0.000008.
# yt : [WARNING  ] 2017-06-02 13:33:10,809 Switching to symlog colorbar scaling unless linear scaling is specified later

# %%
ds = yt.load("TaylorGreen.0002.vtk")
p=yt.SlicePlot(ds,"z", "velocity_z", origin= "native")
#p.annotate_magnetic_field()
#
#p.annotate_velocity(factor = 16)
p.annotate_quiver('x', 'y')
#p.save()
